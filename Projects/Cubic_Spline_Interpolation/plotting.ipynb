# %%
# Plotting for C++ cubic spline project

import matplotlib.pyplot as plt
import pandas as pd

# Read CSV file - each row becomes a row in the DataFrame
df = pd.read_csv('output.csv', header=None)

df = df.transpose()

df.columns = ['x', 'y']
df

# df_2 = pd.read_csv('output.csv', header=None)

# df_2 = df_2.transpose()

# df_2.columns = ['x', 'y']
# df_2
# Out:
#       x        y
# 0  -2.0 -2.00000
# 1  -1.9 -1.78069
# 2  -1.8 -1.56242
# 3  -1.7 -1.34624
# 4  -1.6 -1.13318
# ..  ...      ...
# 58  3.6  1.61623
# 59  3.7  1.95068
# 60  3.8  2.29499
# 61  3.9  2.64585
# 62  4.0  3.00000
#
# [63 rows x 2 columns]

# %%
# Known Values
a = [-2, 0, 3, 4]
b = [-2, 1, 0, 3]

plt.scatter(a,b, color='r')
plt.plot(df['x'], df['y'])
# plt.plot(df_2['x'], df_2['y'], linestyle='--')
plt.show()
