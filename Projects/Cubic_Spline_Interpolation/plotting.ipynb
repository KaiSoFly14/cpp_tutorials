# %%
# Plotting for C++ cubic spline project

import matplotlib.pyplot as plt
import pandas as pd
import cubicspline

import math
# x = [0.0, math.pi/2, math.pi, 3*math.pi/2, 2*math.pi]
# y = [0.0, 1.0, 0.0, -1.0, 0.0]
# n = 5

x = [0.0, 0.1, 0.5, 0.6, 1.0, 2.0]
y = [0.0, 0.5, 1.2, 1.1, 0.8, 0.3]
n = 6

# x = [0.0, 1.0, 2.0, 2.1, 3.0, 4.0]
# y = [0.0, 1.0, 1.0, 3.0, 1.0, 0.0]
# n = 6

# a = [-2, 0, 3, 4]
# b = [-2, 1, 0, 3]

result = cubicspline.cubicSpline(x, y, n)
df = pd.DataFrame({'x': result[0], 'y': result[1]})

# %%
plt.scatter(df['x'], df['y'])
plt.scatter(x,y, color='r')
plt.plot(df['x'], df['y'])


plt.show()
